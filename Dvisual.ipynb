# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas 
from matplotlib.figure import Figure
fig = Figure()
canvas = FigureCanvas(fig)

# %%
x = np.random.randn(10000)

ax = fig.add_subplot(111)

# %%
ax.hist(x, 100)
# Out:
# (array([  1.,   1.,   1.,   1.,   1.,   2.,   2.,   0.,   3.,   2.,   8.,
#           5.,  11.,  11.,  13.,  20.,  19.,  24.,  23.,  29.,  34.,  32.,
#          50.,  52.,  61.,  68.,  93.,  90., 112., 114., 121., 152., 152.,
#         175., 172., 197., 194., 193., 239., 247., 259., 295., 299., 289.,
#         292., 274., 313., 292., 295., 298., 297., 291., 301., 282., 287.,
#         243., 238., 237., 189., 205., 198., 167., 169., 129., 128., 126.,
#         132.,  89., 105.,  67.,  70.,  56.,  58.,  42.,  45.,  38.,  29.,
#          25.,  29.,  17.,  13.,  14.,   9.,   9.,   5.,   8.,   4.,   3.,
#           4.,   2.,   3.,   0.,   0.,   0.,   2.,   0.,   2.,   0.,   1.,
#           1.]),
#  array([-3.64087575e+00, -3.56498531e+00, -3.48909487e+00, -3.41320443e+00,
#         -3.33731399e+00, -3.26142355e+00, -3.18553311e+00, -3.10964267e+00,
#         -3.03375223e+00, -2.95786179e+00, -2.88197135e+00, -2.80608091e+00,
#         -2.73019047e+00, -2.65430003e+00, -2.57840959e+00, -2.50251915e+00,
#         -2.42662871e+00, -2.35073827e+00, -2.27484783e+00, -2.19895739e+00,
#         -2.12306695e+00, -2.04717651e+00, -1.97128607e+00, -1.89539563e+00,
#         -1.81950519e+00, -1.74361475e+00, -1.66772431e+00, -1.59183387e+00,
#         -1.51594343e+00, -1.44005299e+00, -1.36416255e+00, -1.28827211e+00,
#         -1.21238167e+00, -1.13649122e+00, -1.06060078e+00, -9.84710344e-01,
#         -9.08819904e-01, -8.32929464e-01, -7.57039023e-01, -6.81148583e-01,
#         -6.05258143e-01, -5.29367702e-01, -4.53477262e-01, -3.77586822e-01,
#         -3.01696381e-01, -2.25805941e-01, -1.49915501e-01, -7.40250606e-02,
#          1.86537973e-03,  7.77558200e-02,  1.53646260e-01,  2.29536701e-01,
#          3.05427141e-01,  3.81317581e-01,  4.57208022e-01,  5.33098462e-01,
#          6.08988902e-01,  6.84879342e-01,  7.60769783e-01,  8.36660223e-01,
#          9.12550663e-01,  9.88441104e-01,  1.06433154e+00,  1.14022198e+00,
#          1.21611242e+00,  1.29200286e+00,  1.36789331e+00,  1.44378375e+00,
#          1.51967419e+00,  1.59556463e+00,  1.67145507e+00,  1.74734551e+00,
#          1.82323595e+00,  1.89912639e+00,  1.97501683e+00,  2.05090727e+00,
#          2.12679771e+00,  2.20268815e+00,  2.27857859e+00,  2.35446903e+00,
#          2.43035947e+00,  2.50624991e+00,  2.58214035e+00,  2.65803079e+00,
#          2.73392123e+00,  2.80981167e+00,  2.88570211e+00,  2.96159255e+00,
#          3.03748299e+00,  3.11337343e+00,  3.18926387e+00,  3.26515431e+00,
#          3.34104475e+00,  3.41693519e+00,  3.49282563e+00,  3.56871607e+00,
#          3.64460651e+00,  3.72049695e+00,  3.79638739e+00,  3.87227783e+00,
#          3.94816828e+00]),
#  <BarContainer object of 100 artists>)

# %%
# // a histogram should be here
ax.set_title("Normal distribution with $\mu=0, \sigma=1$")
fig.savefig('matplotlib_histogram.png')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [6], line 4
#       2 ax.set_title("Normal distribution with $\mu=0, \sigma=1$")
#       3 fig.savefig('matplotlib_histogram.png')
# ----> 4 fig.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\figure.py:2630, in Figure.show(self, warn)
#    2603 """
#    2604 If using a GUI backend with pyplot, display the figure window.
#    2605
#    (...)
#    2627     unset DISPLAY), issue warning when called on a non-GUI backend.
#    2628 """
#    2629 if self.canvas.manager is None:
# -> 2630     raise AttributeError(
#    2631         "Figure.show works only for figures managed by pyplot, "
#    2632         "normally created by pyplot.figure()")
#    2633 try:
#    2634     self.canvas.manager.show()
#
# AttributeError: Figure.show works only for figures managed by pyplot, normally created by pyplot.figure()

# %%
plt.hist(x, 100)
plt.title("Normal distribution with $\mu=0, \sigma=1$")
plt.savefig('matplotlib_histogram.png')
plt.show()

# %%
plt.plot(5, 5, 'o')
